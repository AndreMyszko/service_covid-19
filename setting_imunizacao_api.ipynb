# %%
import requests
from requests.auth import HTTPBasicAuth

# %%
url = 'https://imunizacao-es.saude.gov.br/_search'

# %%
r = requests.get(url, auth=HTTPBasicAuth('imunizacao_public','qlto5t&7r_@+#Tlstigi'))
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{"took":9003,"timed_out":false,"_shards":{"total":3,"successful":3,"skipped":0,"failed":0},"hits":{"total":{"value":10000,"relation":"gte"},"max_score":1.0,"hits":[{"_index":"desc-imunizacao","_type":"_doc","_id":"0eebbacc-1fa8-4447-b839-010e714f512b-i0b0","_score":1.0,"_source":{"paciente_id":"03fcfb7ca3b42888eb61871960b9a9af74b1154844afd2a650571234f13276c4","document_id":"0eebbacc-1fa8-4447-b839-010e714f512b-i0b0","paciente_endereco_coIbgeMunicipio":"291080","@timestamp":"2021-04-22T20:51:12.669Z","estabelecimento_razaoSocial":"PREFEITURA MUNICIPAL DE FEIRA DE SANTANA","vacina_codigo":"85","estabelecimento_municipio_codigo":"291080","paciente_nacionalidade_enumNacionalidade":"B","vacina_grupoAtendimento_codigo":"001003","paciente_endereco_nmPais":"BRASIL","vacina_dataAplicacao":"2021-04-17T00:00:00.000Z","estabelecimento_municipio_nome":"FEIRA DE SANTANA","paciente_endereco_coPais":"10","vacina_lote":"32401","sistema_origem":"IDS Saúde","vacina_nome":"Vacina Covid-19 - Covishield","@version":"1","paciente_endereco_uf":"BA","estalecimento_noFantasia":"REDE FRIO","vacina_fabricante_nome":"FUNDACAO OSWALDO CRUZ","vacina_descricao_dose":"\xa0\xa0\xa0\xa01ª\xa0Dose","estabelecimento_uf":"BA","paciente_racaCor_codigo":"99","paciente_racaCor_valor":"SEM INFORMACAO","paciente_enumSexoBiologico":"M","data_importacao_rnds":"2021-04-17 13:03:41","id_sistema_origem":"17958","paciente_dataNascimento":"1959-07-02","estabelecimento_valor":"7430671","paciente_endereco_cep":"44068","paciente_idade":61,"paciente_endereco_nmMunicipio":"FEIRA DE SANTANA"}},{"_index":"desc-imunizacao","_type":"_doc","_id":"0f635954-aba8-49c2-9110-563b8dbdbcca-i0b0","_score":1.0,"_source":{"paciente_id":"bc34e151267078ba2189c921b9311dc35cc1076b8bab8782a705fce9a4cec190","document_id":"0f635954-aba8-49c2-9110-563b8dbdbcca-i0b0","paciente_endereco_coIbgeMunicipio":"291080","@timestamp":"2021-04-22T20:51:12.753Z","estabelecimento_razaoSocial":"PREFEITURA MUNICIPAL DE FEIRA DE SANTANA","vacina_codigo":"85","estabelecimento_municipio_codigo":"291080","paciente_nacionalidade_enumNacionalidade":"B","vacina_grupoAtendimento_codigo":"001005","paciente_endereco_nmPais":"BRASIL","vacina_dataAplicacao":"2021-04-12T00:00:00.000Z","estabelecimento_municipio_nome":"FEIRA DE SANTANA","paciente_endereco_coPais":"10","vacina_lote":"32401","sistema_origem":"IDS Saúde","vacina_nome":"Vacina Covid-19 - Covishield","@version":"1","paciente_endereco_uf":"BA","estalecimento_noFantasia":"REDE FRIO","vacina_fabricante_nome":"FUNDACAO OSWALDO CRUZ","vacina_descricao_dose":"\xa0\xa0\xa0\xa01ª\xa0Dose","estabelecimento_uf":"BA","paciente_racaCor_codigo":"04","paciente_racaCor_valor":"AMARELA","paciente_enumSexoBiologico":"F","data_importacao_rnds":"2021-04-12 12:57:14","id_sistema_origem":"17958","paciente_dataNascimento":"1957-02-09","estabelecimento_valor":"7430671","paciente_endereco_cep":"","paciente_idade":64,"paciente_endereco_nmMunicipio":"FEIRA DE SANTANA"}},{"_index":"desc-imunizacao","_type":"_doc","_id":"8da343dc-a250-4a91-afd1-01edf76d6f0e-i0b0","_score":1.0,"_source":{"paciente_id":"6734c2aa1b5829717591f2e64ae024487e3099f03d02b55801e9535a5639994d","document_id":"8da343dc-a250-4a91-afd1-01edf76d6f0e-i0b0","paciente_endereco_coIbgeMunicipio":"353730","vacina_categoria_codigo":"9","@timestamp":"2021-04-22T20:51:26.001Z","estabelecimento_razaoSocial":"PREFEITURA MUNICIPAL DE PENAPOLIS","vacina_codigo":"86","estabelecimento_municipio_codigo":"353730","paciente_nacionalidade_enumNacionalidade":"B","vacina_categoria_nome":"Trabalhadores de Saúde","vacina_grupoAtendimento_codigo":"000926","paciente_endereco_nmPais":"BRASIL","vacina_dataAplicacao":"2021-04-15T00:00:00.000Z","estabelecimento_municipio_nome":"PENAPOLIS","paciente_endereco_coPais":"10","vacina_lote":"210107","sistema_origem":"VACIVIDA","vacina_nome":"Covid-19-Coronavac-Sinovac/Butantan","@version":"1","paciente_endereco_uf":"SP","estalecimento_noFantasia":"MACRO II CENTRO DE SAUDE DE PENAPOLIS","vacina_grupoAtendimento_nome ...
