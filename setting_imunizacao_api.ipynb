# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import pandas as pd

# %%
url = 'https://imunizacao-es.saude.gov.br/_search'

# %%
r = requests.get(url, auth=HTTPBasicAuth('imunizacao_public','qlto5t&7r_@+#Tlstigi'))
#r.text

# %%
vacina = r.json()
vacina_txt = r.text
#vacina
vacina ['hits']['hits']
# Out:
# [{'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': '0eebbacc-1fa8-4447-b839-010e714f512b-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': '03fcfb7ca3b42888eb61871960b9a9af74b1154844afd2a650571234f13276c4',
#    'document_id': '0eebbacc-1fa8-4447-b839-010e714f512b-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '291080',
#    '@timestamp': '2021-04-22T20:51:12.669Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE FEIRA DE SANTANA',
#    'vacina_codigo': '85',
#    'estabelecimento_municipio_codigo': '291080',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_grupoAtendimento_codigo': '001003',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-04-17T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'FEIRA DE SANTANA',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '32401',
#    'sistema_origem': 'IDS Saúde',
#    'vacina_nome': 'Vacina Covid-19 - Covishield',
#    '@version': '1',
#    'paciente_endereco_uf': 'BA',
#    'estalecimento_noFantasia': 'REDE FRIO',
#    'vacina_fabricante_nome': 'FUNDACAO OSWALDO CRUZ',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'estabelecimento_uf': 'BA',
#    'paciente_racaCor_codigo': '99',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_enumSexoBiologico': 'M',
#    'data_importacao_rnds': '2021-04-17 13:03:41',
#    'id_sistema_origem': '17958',
#    'paciente_dataNascimento': '1959-07-02',
#    'estabelecimento_valor': '7430671',
#    'paciente_endereco_cep': '44068',
#    'paciente_idade': 61,
#    'paciente_endereco_nmMunicipio': 'FEIRA DE SANTANA'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': '0f635954-aba8-49c2-9110-563b8dbdbcca-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': 'bc34e151267078ba2189c921b9311dc35cc1076b8bab8782a705fce9a4cec190',
#    'document_id': '0f635954-aba8-49c2-9110-563b8dbdbcca-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '291080',
#    '@timestamp': '2021-04-22T20:51:12.753Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE FEIRA DE SANTANA',
#    'vacina_codigo': '85',
#    'estabelecimento_municipio_codigo': '291080',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_grupoAtendimento_codigo': '001005',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-04-12T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'FEIRA DE SANTANA',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '32401',
#    'sistema_origem': 'IDS Saúde',
#    'vacina_nome': 'Vacina Covid-19 - Covishield',
#    '@version': '1',
#    'paciente_endereco_uf': 'BA',
#    'estalecimento_noFantasia': 'REDE FRIO',
#    'vacina_fabricante_nome': 'FUNDACAO OSWALDO CRUZ',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'estabelecimento_uf': 'BA',
#    'paciente_racaCor_codigo': '04',
#    'paciente_racaCor_valor': 'AMARELA',
#    'paciente_enumSexoBiologico': 'F',
#    'data_importacao_rnds': '2021-04-12 12:57:14',
#    'id_sistema_origem': '17958',
#    'paciente_dataNascimento': '1957-02-09',
#    'estabelecimento_valor': '7430671',
#    'paciente_endereco_cep': '',
#    'paciente_idade': 64,
#    'paciente_endereco_nmMunicipio': 'FEIRA DE SANTANA'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': '8da343dc-a250-4a91-afd1-01edf76d6f0e-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': '6734c2aa1b5829717591f2e64ae024487e3099f03d02b55801e9535a5639994d',
#    'document_id': '8da343dc-a250-4a91-afd1-01edf76d6f0e-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '353730',
#    'vacina_categoria_codigo': '9',
#    '@timestamp': '2021-04-22T20:51:26.001Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE PENAPOLIS',
#    'vacina_codigo': '86',
#    'estabelecimento_municipio_codigo': '353730',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-04-15T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'PENAPOLIS',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '210107',
#    'sistema_origem': 'VACIVIDA',
#    'vacina_nome': 'Covid-19-Coronavac-Sinovac/Butantan',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'estalecimento_noFantasia': 'MACRO II CENTRO DE SAUDE DE PENAPOLIS',
#    'vacina_grupoAtendimento_nome': 'Outros',
#    'vacina_fabricante_nome': 'SINOVAC',
#    'estabelecimento_uf': 'SP',
#    'paciente_racaCor_codigo': '01',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa02ª\xa0Dose',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'M',
#    'data_importacao_rnds': '2021-04-15 03:00:00',
#    'id_sistema_origem': '18262',
#    'paciente_dataNascimento': '1990-11-08',
#    'estabelecimento_valor': '2028387',
#    'paciente_endereco_cep': '16308',
#    'paciente_idade': 30,
#    'paciente_endereco_nmMunicipio': 'PENAPOLIS'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': '632bf364-f835-4fd9-a194-2626041c6025-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': '5b9db1d75a761d42aa510fd7362d3978e2c03146f2b3f17a73ad693e9bd2d10c',
#    'document_id': '632bf364-f835-4fd9-a194-2626041c6025-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '351840',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2021-04-22T20:51:21.566Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE GUARATINGUETA',
#    'vacina_codigo': '86',
#    'estabelecimento_municipio_codigo': '351840',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_grupoAtendimento_codigo': '000203',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-04-19T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'GUARATINGUETA',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '210098',
#    'sistema_origem': 'VACIVIDA',
#    'vacina_nome': 'Covid-19-Coronavac-Sinovac/Butantan',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'estalecimento_noFantasia': 'UBS PARQUE SAO FRANCISCO',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 70 a 74 anos',
#    'vacina_fabricante_nome': 'SINOVAC',
#    'estabelecimento_uf': 'SP',
#    'paciente_racaCor_codigo': '99',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa02ª\xa0Dose',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_enumSexoBiologico': 'F',
#    'data_importacao_rnds': '2021-04-19 03:00:00',
#    'id_sistema_origem': '18262',
#    'paciente_dataNascimento': '1948-06-26',
#    'estabelecimento_valor': '2060256',
#    'paciente_endereco_cep': '',
#    'paciente_idade': 72,
#    'paciente_endereco_nmMunicipio': 'GUARATINGUETA'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': 'd01a1c5c-b44b-43df-9f37-e88b49dff285-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': '0e35be8d728bd8da52dadb269d89050f494968df9a4af11d42f028fac5855612',
#    'document_id': 'd01a1c5c-b44b-43df-9f37-e88b49dff285-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '240810',
#    'vacina_categoria_codigo': '9',
#    '@timestamp': '2021-04-22T20:51:34.983Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE SAO GONCALO DO AMARANTE',
#    'vacina_codigo': '86',
#    'estabelecimento_municipio_codigo': '241200',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-04-20T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'SAO GONCALO DO AMARANTE',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '210112',
#    'sistema_origem': 'RN + Vacina',
#    'vacina_nome': 'Covid-19-Coronavac-Sinovac/Butantan',
#    '@version': '1',
#    'paciente_endereco_uf': 'RN',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE DA FAMILIA DE JARDIM PETROPOLIS',
#    'vacina_grupoAtendimento_nome': 'Outros',
#    'vacina_fabricante_nome': 'FUNDACAO BUTANTAN',
#    'estabelecimento_uf': 'RN',
#    'paciente_racaCor_codigo': '03',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa02ª\xa0Dose',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_enumSexoBiologico': 'F',
#    'data_importacao_rnds': '2021-04-20 15:04:19',
#    'id_sistema_origem': '17862',
#    'paciente_dataNascimento': '1994-10-10',
#    'estabelecimento_valor': '7081251',
#    'paciente_endereco_cep': '59114',
#    'paciente_idade': 26,
#    'paciente_endereco_nmMunicipio': 'NATAL'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': 'f000d894-42f1-410a-bc5d-e410cb702575-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': 'fd4326c313026620012301e6c424043c37bc64984c4a057f910a7755cba83296',
#    'document_id': 'f000d894-42f1-410a-bc5d-e410cb702575-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '352720',
#    'vacina_categoria_codigo': '3',
#    '@timestamp': '2021-04-22T20:34:30.245Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE LORENA',
#    'vacina_codigo': '86',
#    'estabelecimento_municipio_codigo': '352720',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Pessoas de 60 anos ou mais institucionalizadas',
#    'vacina_grupoAtendimento_codigo': '000301',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-01-26T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'LORENA',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '202010033',
#    'sistema_origem': 'VACIVIDA',
#    'vacina_nome': 'Covid-19-Coronavac-Sinovac/Butantan',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'estalecimento_noFantasia': 'USF SAO ROQUE PSF',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 60 nos ou mais Institucionalizadas',
#    'vacina_fabricante_nome': 'SINOVAC',
#    'estabelecimento_uf': 'SP',
#    'paciente_racaCor_codigo': '01',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'M',
#    'data_importacao_rnds': '2021-01-26 03:01:00',
#    'id_sistema_origem': '18262',
#    'paciente_dataNascimento': '1953-11-16',
#    'estabelecimento_valor': '7321708',
#    'paciente_endereco_cep': '12601',
#    'paciente_idade': 67,
#    'paciente_endereco_nmMunicipio': 'LORENA'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': 'c5db5988-a1ef-44fb-9492-ffa6369a3d32-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': 'fa233848791d6215b99e742d57a8754349127ffd6151435681dd0452b742ce56',
#    'document_id': 'c5db5988-a1ef-44fb-9492-ffa6369a3d32-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '355700',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2021-04-22T20:34:31.863Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE VOTORANTIM',
#    'vacina_codigo': '86',
#    'estabelecimento_municipio_codigo': '355700',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_grupoAtendimento_codigo': '000203',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-03-26T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'VOTORANTIM',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '210083',
#    'sistema_origem': 'VACIVIDA',
#    'vacina_nome': 'Covid-19-Coronavac-Sinovac/Butantan',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'estalecimento_noFantasia': 'HOSPITAL MUNICIPAL DE VOTORANTIM',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 70 a 74 anos',
#    'vacina_fabricante_nome': 'SINOVAC',
#    'estabelecimento_uf': 'SP',
#    'paciente_racaCor_codigo': '01',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'M',
#    'data_importacao_rnds': '2021-03-26 03:03:00',
#    'id_sistema_origem': '18262',
#    'paciente_dataNascimento': '1949-02-12',
#    'estabelecimento_valor': '2087618',
#    'paciente_endereco_cep': '',
#    'paciente_idade': 72,
#    'paciente_endereco_nmMunicipio': 'VOTORANTIM'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': '8a314b46-bd83-4240-bee6-43ff464693a3-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': 'f37284ace4b14a04a8d68d240004b7fe9935927f869659d31cf07346a0a7d6dd',
#    'document_id': '8a314b46-bd83-4240-bee6-43ff464693a3-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2021-04-22T20:34:31.907Z',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BELO HORIZONTE',
#    'vacina_codigo': '85',
#    'estabelecimento_municipio_codigo': '310620',
#    'vacina_fabricante_referencia': 'Organization/33781055000135',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_grupoAtendimento_codigo': '000205',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-02-12T03:00:00.000Z',
#    'estabelecimento_municipio_nome': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '4120Z005',
#    'sistema_origem': 'Novo PNI',
#    'vacina_nome': 'Vacina Covid-19 - Covishield',
#    '@version': '1',
#    'paciente_endereco_uf': 'MG',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE SANTA TEREZINHA',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 80 anos ou mais',
#    'vacina_fabricante_nome': 'FUNDACAO OSWALDO CRUZ',
#    'estabelecimento_uf': 'MG',
#    'paciente_racaCor_codigo': '01',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'F',
#    'data_importacao_rnds': '2021-02-12 23:03:40',
#    'id_sistema_origem': '16341',
#    'paciente_dataNascimento': '1925-10-26',
#    'estabelecimento_valor': '0023558',
#    'paciente_endereco_cep': '31110',
#    'paciente_idade': 95,
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': 'dcf95d85-3267-4308-b0b1-6a3a6654150d-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': 'b9a27baa39e5bee82a37d23bd296328d0ea6a9f04e1e67837b8a4dca44295038',
#    'document_id': 'dcf95d85-3267-4308-b0b1-6a3a6654150d-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '355670',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2021-04-22T20:34:32.205Z',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE VINHEDO',
#    'vacina_codigo': '86',
#    'estabelecimento_municipio_codigo': '355670',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_grupoAtendimento_codigo': '000204',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-03-17T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'VINHEDO',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '210044',
#    'sistema_origem': 'VACIVIDA',
#    'vacina_nome': 'Covid-19-Coronavac-Sinovac/Butantan',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE PLANALTO',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 75 a 79 anos',
#    'vacina_fabricante_nome': 'SINOVAC',
#    'estabelecimento_uf': 'SP',
#    'paciente_racaCor_codigo': '01',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'F',
#    'data_importacao_rnds': '2021-03-17 03:03:00',
#    'id_sistema_origem': '18262',
#    'paciente_dataNascimento': '1943-08-10',
#    'estabelecimento_valor': '2064898',
#    'paciente_endereco_cep': '13280',
#    'paciente_idade': 77,
#    'paciente_endereco_nmMunicipio': 'VINHEDO'}},
#  {'_index': 'desc-imunizacao',
#   '_type': '_doc',
#   '_id': 'c11f5273-faa7-44d9-8ecd-46bfb69a912e-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_id': '11d9c8ed67ebc91d8ae26b28e2c02a896b92bbcd964b545eeb465b76e326e756',
#    'document_id': 'c11f5273-faa7-44d9-8ecd-46bfb69a912e-i0b0',
#    'paciente_endereco_coIbgeMunicipio': '230435',
#    '@timestamp': '2021-04-22T20:34:32.405Z',
#    'estabelecimento_razaoSocial': 'PREF M FORQUILHA',
#    'vacina_codigo': '85',
#    'estabelecimento_municipio_codigo': '230435',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_grupoAtendimento_codigo': '00',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_dataAplicacao': '2021-01-28T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'FORQUILHA',
#    'paciente_endereco_coPais': '10',
#    'vacina_lote': '4120Z005',
#    'sistema_origem': 'ESUS APS - NACIONAL (OFFLINE)',
#    'vacina_nome': 'Vacina Covid-19 - Covishield',
#    '@version': '1',
#    'paciente_endereco_uf': 'CE',
#    'estalecimento_noFantasia': 'UBS OTILIA LOPES DE SOUSA UBS 3',
#    'vacina_fabricante_nome': 'SINOVAC LIFE SCIENCE CO LTD',
#    'vacina_descricao_dose': '\xa0\xa0\xa0\xa01ª\xa0Dose',
#    'estabelecimento_uf': 'CE',
#    'paciente_racaCor_codigo': '04',
#    'paciente_racaCor_valor': 'AMARELA',
#    'paciente_enumSexoBiologico': 'M',
#    'data_importacao_rnds': '2021-02-22 14:28:35',
#    'id_sistema_origem': '18602',
#    'paciente_dataNascimento': '1927-05-06',
#    'estabelecimento_valor': '2664356',
#    'paciente_endereco_cep': '62115',
#    'paciente_idade': 93,
#    'paciente_endereco_nmMunicipio': 'FORQUILHA'}}]
